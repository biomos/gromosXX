# %%
import os

# %%
os.getcwd()
# Out:
# '/home/deruiter/2DEDS/multiAEDS/gromosXX/gromosXX/src/io/configuration'

# %%
# %cd /pool/deruiter/2DEDS/test_multiAEDS/propionic
# Out:
# /pool/deruiter/2DEDS/test_multiAEDS/propionic

# %%
# %ls
# Out:
# 1eby.cif  Bene/  eq/             ions/   min/           multiAEDS_41/
# 1ebz.cif  box/   even_further/   md_14/  multiAEDS/     propionic_AEDS/
# bene/     conf/  further_apart/  md_41/  multiAEDS_14/  topo/

# %%
# %cd propionic_AEDS/
# %ls
# Out:
# /pool/deruiter/2DEDS/test_multiAEDS/propionic/propionic_AEDS
# AEDS/  box/  eq/

# %%
# %cd AEDS/ana
# Out:
# /pool/deruiter/2DEDS/test_multiAEDS/propionic/propionic_AEDS/AEDS/ana

# %%
# %ls
# Out:
# calc_pi.py*  e2s.dat  e5r.dat              ene_ana.arg
# df.arg       e3.dat   e5s.dat              ene_ana.md++_multiaeds.lib
# dfmult.out   e3r.dat  eds_emax.dat         ene_ana.out
# e1.dat       e3s.dat  eds_emin.dat         pi_all.dat
# e1r.dat      e4.dat   eds_globmin.dat      sampled_states.dat
# e1s.dat      e4r.dat  eds_globminfluc.dat  sampling.out
# e2.dat       e4s.dat  eds_vmix.dat         sampling.py*
# e2r.dat      e5.dat   eds_vr.dat

# %%
import matplotlib

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
eds_vr_aeds = np.loadtxt("eds_vr.dat")
eds_vmix_aeds = np.loadtxt("eds_vmix.dat")
data2=np.loadtxt("../../../multiAEDS/ana/vmix.dat")

# %%
print(np.max(data2[::,1]))
print(np.max(data2[::,2]))
# Out:
# -613.287381
# -598.745654

# %%
aeds_time=eds_vr_aeds[:,0]
aeds_vr=eds_vr_aeds[:,1]
aeds_vmix=eds_vmix_aeds[:,1]

maeds_time = data2[:,0]
maeds_vmix1 = data2[:,1]
maeds_vmix2 = data2[:,2]
plt.figure(figsize=(6, 3),dpi=300) 
plt.plot(aeds_time, aeds_vr,label='aesd_vr')
plt.plot(aeds_time, aeds_vmix,label='aesd_vmix')
plt.plot(maeds_time,maeds_vmix1,label='maeds_vmix1')
plt.plot(maeds_time,maeds_vmix2, label='maeds_vmix2')
plt.legend(prop={"size":6})
plt.show()

# %%
plt.plot(aeds_time, aeds_vr)
plt.plot(maeds_time,maeds_v1)
plt.plot(maeds_time,maeds_v2)
plt.show()
